# %% [markdown]
# # Ettoday 網路爬蟲實作練習
#
#
# * 能夠利用 Request + BeatifulSour 撰寫爬蟲，並存放到合適的資料結構

# %% [markdown]
# ## 作業目標
#
# 根據範例：
#
# 1. 取出今天所有的新聞
# 2. 取出現在時間兩小時內的新聞
# 3. 根據範例，取出三天前下午三點到五點的新聞

# %% [markdown]
# ## 1. 取出今天所有的新聞

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import re
from selenium.webdriver.support.ui import Select

# %%
browser = webdriver.Chrome(executable_path='./chromedriver')
browser.get("https://www.ettoday.net/news/news-list.htm")

# %%
for i in range(10):
    time.sleep(2)
    browser.execute_script("window.scrollTo(0, 10000);")
# .execute_script 是 java script 的語法，其中 (0, 10000) 代標將畫面移動到指定 (x座標 ,y座標)

# %%
html_source = browser.page_source # 取得網頁原始碼
soup = BeautifulSoup(html_source, "html5lib")

# %%
for d in soup.find("div", class_ = "part_list_2").find_all("h3"):
    if re.findall("2020/03/18",d.find(class_ = "date").text): # 要注意
        print(d.find(class_ = "date").text,d.find("a").text)
# Out:
# 2020/03/18 15:18 限制國人出境？　黃暐瀚：違憲，但支持！
# 2020/03/18 15:17 中國改推「科學戴口罩」　衛健委：公眾無聚集、通風良好可不戴
# 2020/03/18 15:17 嘉義市2車相撞　2騎士待轉區等紅燈慘遭波及送醫
# 2020/03/18 15:16 國王全隊嚴格執行居家隔離　至今未出現新冠肺炎症狀
# 2020/03/18 15:16 孩住院「院方限制只能1人陪」　媽24hrs僅上一次廁所苦喊：別再出國崩壞醫療
# 2020/03/18 15:15 華航、長榮機組員即日起免責14天居家檢疫　恐成破口？指揮中心說明了
# 2020/03/18 15:14 福斯關閉4國工廠、福特3員工確診新冠肺炎！汽機車大廠陸續停工
# 2020/03/18 15:13 毀滅到數？疾控專家佛西：美國疫情頂峰或在45天後到達
# 2020/03/18 15:12 中華醫大製藥工程系就業博覽　配合疫情防護全戴口罩上陣
# 2020/03/18 15:12 《梨泰院Class》定情物起底！Tiffany 微笑項鍊要價159,000元
# 2020/03/18 15:11 口罩2.0預購今截止！　「手機格式輸錯」指揮中心將寄電郵提醒
# 2020/03/18 15:10 恆春旅遊醫院計畫2021年竣工　目前卻還未招標…偏鄉醫療惹議
# 2020/03/18 15:10 「電子圍籬智慧監控系統」啟動　居家隔離亂跑會收到「告警簡訊」
# 2020/03/18 15:10 不斷更新／WHO鎖定東南亞感染「要積極抗疫」　印度軍方首例確診
# 2020/03/18 15:09 埃及團確診者返台「傳染給小孩」　陳時中：本來就來列在親密接觸者
# 2020/03/18 15:08 孩子口罩戴不住？治療師建議：試著讓他「有樣學樣」
# 2020/03/18 15:08 韓國4機場停飛國際航線　預估全年營業額減5664億
# 2020/03/18 15:08 德媒推崇台灣防疫　謝志偉曝關鍵「別相信中國」
# 2020/03/18 15:04 江啟臣：主席辦公室設「數位行銷科技長」　將公開徵才海選
# 2020/03/18 15:04 疫情衝擊！靜岡人氣鰻魚派暫停生產　北海道螃蟹、肉品過剩發SOS
# ...

# %%
localtime = time.asctime( time.localtime(time.time()) )
print(localtime)
# Out:
# Wed Mar 18 15:56:12 2020

# %%
print(int(localtime[11:13]))
# Out:
# 15

# %% [markdown]
# ## 2. 取出現在時間兩小時內的新聞

# %%
for d in soup.find("div", class_ = "part_list_2").find_all("h3"):
    if re.findall("2020/03/18",d.find(class_ = "date").text) and localtime_hr>=int(d.find(class_ = "date").text[11:13])>localtime_hr-2:
        print(d.find(class_ = "date").text,d.find("a").text)
# Out:
# 2020/03/18 15:18 限制國人出境？　黃暐瀚：違憲，但支持！
# 2020/03/18 15:17 中國改推「科學戴口罩」　衛健委：公眾無聚集、通風良好可不戴
# 2020/03/18 15:17 嘉義市2車相撞　2騎士待轉區等紅燈慘遭波及送醫
# 2020/03/18 15:16 國王全隊嚴格執行居家隔離　至今未出現新冠肺炎症狀
# 2020/03/18 15:16 孩住院「院方限制只能1人陪」　媽24hrs僅上一次廁所苦喊：別再出國崩壞醫療
# 2020/03/18 15:15 華航、長榮機組員即日起免責14天居家檢疫　恐成破口？指揮中心說明了
# 2020/03/18 15:14 福斯關閉4國工廠、福特3員工確診新冠肺炎！汽機車大廠陸續停工
# 2020/03/18 15:13 毀滅到數？疾控專家佛西：美國疫情頂峰或在45天後到達
# 2020/03/18 15:12 中華醫大製藥工程系就業博覽　配合疫情防護全戴口罩上陣
# 2020/03/18 15:12 《梨泰院Class》定情物起底！Tiffany 微笑項鍊要價159,000元
# 2020/03/18 15:11 口罩2.0預購今截止！　「手機格式輸錯」指揮中心將寄電郵提醒
# 2020/03/18 15:10 恆春旅遊醫院計畫2021年竣工　目前卻還未招標…偏鄉醫療惹議
# 2020/03/18 15:10 「電子圍籬智慧監控系統」啟動　居家隔離亂跑會收到「告警簡訊」
# 2020/03/18 15:10 不斷更新／WHO鎖定東南亞感染「要積極抗疫」　印度軍方首例確診
# 2020/03/18 15:09 埃及團確診者返台「傳染給小孩」　陳時中：本來就來列在親密接觸者
# 2020/03/18 15:08 孩子口罩戴不住？治療師建議：試著讓他「有樣學樣」
# 2020/03/18 15:08 韓國4機場停飛國際航線　預估全年營業額減5664億
# 2020/03/18 15:08 德媒推崇台灣防疫　謝志偉曝關鍵「別相信中國」
# 2020/03/18 15:04 江啟臣：主席辦公室設「數位行銷科技長」　將公開徵才海選
# 2020/03/18 15:04 疫情衝擊！靜岡人氣鰻魚派暫停生產　北海道螃蟹、肉品過剩發SOS
# ...

# %% [markdown]
# ## 3. 根據範例，取出三天前下午三點到五點的新聞

# %%
browser = webdriver.Chrome(executable_path='./chromedriver')
browser.get("https://www.ettoday.net/news/news-list.htm")

# %%
selectSite = Select(browser.find_element_by_id("selD"))
selectSite.select_by_value('15')
browser.find_element_by_id('button').click()

# %%
for i in range(10):
    time.sleep(2)
    browser.execute_script("window.scrollTo(0, 10000);")

# %%
html_source = browser.page_source # 取得網頁原始碼
soup = BeautifulSoup(html_source, "html5lib")

# %%
for d in soup.find("div", class_ = "part_list_2").find_all("h3"):
    if re.findall("2020/03/15",d.find(class_ = "date").text) and 17>=int(d.find(class_ = "date").text[11:13])>=15:
        print(d.find(class_ = "date").text,d.find("a").text)
# Out:
# 2020/03/15 17:57 保持「社交距離」相隔2m避傳染！專家點關鍵：記得1995年熱浪教訓
# 2020/03/15 17:57 約克夏萌腿狂奔！柔順長毛飄起「小臉遮不住」　網讚：超高級拖把
# 2020/03/15 17:50 北京防疫高規格！　「上班穿哈利波特透明罩、吃飯用公筷母匙」
# 2020/03/15 17:46 中學五人制／給球員舞台發揮　北門拿第五創最佳表現受肯定
# 2020/03/15 17:46 「杜拜→波士頓」機上男乘客過世！有印度旅遊史　將檢驗是否感染新冠肺炎
# 2020/03/15 17:44 SBL／史上第17位　簡浩生涯3000分達陣
# 2020/03/15 17:44 蜂群大舉「進攻」警察局！　免驚啦...原來是跟著蜂王找新家
# 2020/03/15 17:44 是誰吃了拖鞋？咖啡汪「甩態撇頭」　堅決否認到底：母系哇啦
# 2020/03/15 17:43 中職／開幕延後羅傑斯降至65球　丘總：放慢節奏
# 2020/03/15 17:41 防疫政策變軟？他納悶政府「讓爽玩歐洲的人回來」　網提議：入境全隔離14天
# 2020/03/15 17:40 美軍停止研發ALQ-131電戰莢艙1.6億泡湯？　空軍澄清：尚無預算投入
# 2020/03/15 17:35 防疫躲在家「吃太胖玉鐲卡住」　阿姨「手快痛死」求消防隊鋸開
# 2020/03/15 17:31 義大利封國！民眾開窗快閃合唱國歌提振士氣「一切都會安好」
# 2020/03/15 17:30 英國衛生大臣：考慮要求70歲以上老人全部自主隔離
# 2020/03/15 17:30 小薰《租屋》被變態房東跟蹤　午夜12點驚悚上線「網友嚇到不敢看」
# 2020/03/15 17:29 超可愛！DHC出《怪獸電力公司》睫毛滋養液、泡沫洗面乳
# 2020/03/15 17:27 奴才忙滑手機！　橘貓遭無視「怒鑽神秘黑洞」變袋鼠寶寶討關注
# 2020/03/15 17:26 新增6例全是「境外移入」　醫求：暫時不要再出國了！拜託！
# 2020/03/15 17:25 湯姆漢克斯確診新冠肺炎第4天「隔離飲食公開」　澳洲美少年驚呆：塗太多啦！
# 2020/03/15 17:25 重返現場找浪浪「有緣就收編」　回家後「對貓一個要求」網全笑噴
# ...
